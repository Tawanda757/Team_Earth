# %%
install.packages('readxl')
library('readxl')
# Out:
# Installing package into 'C:/Users/TRAIG/AppData/Local/R/win-library/4.2'
# (as 'lib' is unspecified)
# package 'readxl' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\TRAIG\AppData\Local\Temp\Rtmp2NdGyr\downloaded_packages
# Warning message:
# "package 'readxl' was built under R version 4.2.3"

# %%
pollution <- read.csv("../Data/globalairpollution.csv")

# %%
pollution
# Out:
#       Country                                              City
# 1     Russian Federation                                   Praskoveya
# 2     Brazil                                               Presidente Dutra
# 3     Italy                                                Priolo Gargallo
# 4     Poland                                               Przasnysz
# 5     France                                               Punaauia
# 6     United States of America                             Punta Gorda
# 7     Germany                                              Puttlingen
# 8     Belgium                                              Puurs
# 9     Russian Federation                                   Pyatigorsk
# 10    Egypt                                                Qalyub
# 11    China                                                Qinzhou
# 12    Netherlands                                          Raalte
# 13    India                                                Radaur
# ...
